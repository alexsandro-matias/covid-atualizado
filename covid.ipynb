# %% [markdown]
# <a href="https://colab.research.google.com/github/alexsandro-matias/covid-atualizado/blob/main/covid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv("https://raw.githubusercontent.com/wcota/covid19br/master/cases-brazil-states.csv")

# %%
state = 'PE'

df = df[df["state"] == state]

df
# Out:
#        epi_week        date country state   city  newDeaths  deaths  newCases  \
# 72           11  2020-03-12  Brazil    PE  TOTAL          0       0         2
# 87           11  2020-03-13  Brazil    PE  TOTAL          0       0         0
# 103          11  2020-03-14  Brazil    PE  TOTAL          0       0         5
# 120          12  2020-03-15  Brazil    PE  TOTAL          0       0         1
# 138          12  2020-03-16  Brazil    PE  TOTAL          0       0         0
# ...         ...         ...     ...   ...    ...        ...     ...       ...
# 24473       231  2022-08-03  Brazil    PE  TOTAL          4   22057      1071
# 24501       231  2022-08-04  Brazil    PE  TOTAL          6   22063      1233
# 24529       231  2022-08-05  Brazil    PE  TOTAL          7   22070      1200
# 24557       231  2022-08-06  Brazil    PE  TOTAL          5   22075       911
# 24585       232  2022-08-07  Brazil    PE  TOTAL          4   22079       271
#
#        totalCases  deathsMS  ...      tests  tests_per_100k_inhabitants  \
# 72              2         0  ...        NaN                         NaN
# 87              2         0  ...        NaN                         NaN
# 103             7         0  ...        NaN                         NaN
# 120             8         0  ...        NaN                         NaN
# 138             8         0  ...        NaN                         NaN
# ...           ...       ...  ...        ...                         ...
# 24473     1031355     22057  ...  3390139.0                 35472.57313
# 24501     1032588     22063  ...  3390139.0                 35472.57313
# 24529     1033788     22070  ...  3390139.0                 35472.57313
# 24557     1034699     22075  ...  3390139.0                 35472.57313
# 24585     1034970     22079  ...  3390139.0                 35472.57313
#
#        vaccinated  vaccinated_per_100_inhabitants  vaccinated_second  \
# 72            NaN                             NaN                NaN
# 87            NaN                             NaN                NaN
# 103           NaN                             NaN                NaN
# 120           NaN                             NaN                NaN
# 138           NaN                             NaN                NaN
# ...           ...                             ...                ...
# 24473   8388502.0                        87.77273          7457791.0
# 24501   8388502.0                        87.77273          7457791.0
# 24529   8402032.0                        87.91430          7475050.0
# 24557   8402735.0                        87.92166          7475765.0
# 24585   8403303.0                        87.92760          7475982.0
#
#        vaccinated_second_per_100_inhabitants  vaccinated_single  \
# 72                                       NaN                NaN
# 87                                       NaN                NaN
# 103                                      NaN                NaN
# 120                                      NaN                NaN
# 138                                      NaN                NaN
# ...                                      ...                ...
# 24473                               78.03427           192926.0
# 24501                               78.03427           192926.0
# 24529                               78.21486           192926.0
# 24557                               78.22234           192926.0
# 24585                               78.22462           192926.0
#
#        vaccinated_single_per_100_inhabitants  vaccinated_third  \
# 72                                       NaN               NaN
# 87                                       NaN               NaN
# 103                                      NaN               NaN
# 120                                      NaN               NaN
# 138                                      NaN               NaN
# ...                                      ...               ...
# 24473                                2.01867         4870219.0
# 24501                                2.01867         4870219.0
# 24529                                2.01867         5179924.0
# 24557                                2.01867         5179924.0
# 24585                                2.01867         5179924.0
#
#        vaccinated_third_per_100_inhabitants
# 72                                      NaN
# 87                                      NaN
# 103                                     NaN
# 120                                     NaN
# 138                                     NaN
# ...                                     ...
# 24473                              50.95933
# 24501                              50.95933
# 24529                              54.19991
# 24557                              54.19991
# 24585                              54.19991
#
# [879 rows x 26 columns]
